# %%
# Given two sets sums and summands of integers and an integer a,
# computes the LONGEST lists of the form
# [a, a + n_1, a + n_1 + n_2, ..., a + n_1 + n_2 + ... + n_k]
# such that:
# - a, a + n_1, a + n_1 + n_2, ..., a + n_1 + n_2 + ... + n_k are all in sums;
# - n_1, n_2, ..., n_k are all in summands and DISTINCT.
#
# The code is already written to print out the lists in lexicographic order
# (together with extra information on how they have been obtained).
#
# You can assume that the function is called with sets of integers
# as first two arguments and with an integer as third argument. 


def chains(sums, summands, a):
    '''
    >>> chains({}, {1, 2, 3}, 1)
    >>> chains({1, 2, 3}, {}, 4)
    >>> chains({1, 2, 3}, {}, 2)
    [2]
    >>> chains({11, 12, 13, 14, 15, 16}, {1, 2, 3, 4}, 11)
    [11, 12, 14] by successively adding 1, 2
    [11, 12, 15] by successively adding 1, 3
    [11, 12, 16] by successively adding 1, 4
    [11, 13, 14] by successively adding 2, 1
    [11, 13, 16] by successively adding 2, 3
    [11, 14, 15] by successively adding 3, 1
    [11, 14, 16] by successively adding 3, 2
    [11, 15, 16] by successively adding 4, 1
    >>> chains({1, 3, 4, 6, 9, 10, 20}, {-30, 1, 2, 3, 5, 6, 30}, 3)
    [3, 4, 6, 9] by successively adding 1, 2, 3
    >>> chains({10, 12, 13, 14, 16, 21, 26, 36, 37, 38, 50},\
               {2, 4, 7, 10, 16, 20, 100}, 10)
    [10, 12, 16, 26] by successively adding 2, 4, 10
    [10, 12, 16, 36] by successively adding 2, 4, 20
    [10, 14, 16, 26] by successively adding 4, 2, 10
    [10, 14, 16, 36] by successively adding 4, 2, 20
    [10, 14, 21, 37] by successively adding 4, 7, 16
    [10, 26, 36, 38] by successively adding 16, 10, 2
    '''
    for L in sorted(_chains(sums, summands, a)):
        if len(L) == 1:
            print(L)
        else:
            print(L, 'by successively adding',
                  ', '.join(str(L[i + 1] - L[i])
                                for i in range(len(L) - 1)
                           )
                 )

def _chains(sums, summands, a):
    return []
    # REPLACE THE RETURN STATEMENT ABOVE WITH YOUR CODE



if __name__ == '__main__':
    import doctest
    doctest.testmod()
# Out:
# **********************************************************************
# File "__main__", line 3, in __main__.chains
# Failed example:
#     chains({}, {1, 2, 3}, 1)
# Expected nothing
# Got:
#     {}
#     {1, 2, 3}
#     1
# **********************************************************************
# File "__main__", line 4, in __main__.chains
# Failed example:
#     chains({1, 2, 3}, {}, 4)
# Expected nothing
# Got:
#     {1, 2, 3}
#     {}
#     4
# **********************************************************************
# File "__main__", line 5, in __main__.chains
# Failed example:
#     chains({1, 2, 3}, {}, 2)
# Expected:
#     [2]
# Got:
#     {1, 2, 3}
#     {}
#     2
# **********************************************************************
# File "__main__", line 7, in __main__.chains
# Failed example:
#     chains({11, 12, 13, 14, 15, 16}, {1, 2, 3, 4}, 11)
# Expected:
#     [11, 12, 14] by successively adding 1, 2
#     [11, 12, 15] by successively adding 1, 3
#     [11, 12, 16] by successively adding 1, 4
#     [11, 13, 14] by successively adding 2, 1
#     [11, 13, 16] by successively adding 2, 3
#     [11, 14, 15] by successively adding 3, 1
#     [11, 14, 16] by successively adding 3, 2
#     [11, 15, 16] by successively adding 4, 1
# Got:
#     {16, 11, 12, 13, 14, 15}
#     {1, 2, 3, 4}
#     11
# **********************************************************************
# File "__main__", line 16, in __main__.chains
# Failed example:
#     chains({1, 3, 4, 6, 9, 10, 20}, {-30, 1, 2, 3, 5, 6, 30}, 3)
# Expected:
#     [3, 4, 6, 9] by successively adding 1, 2, 3
# Got:
#     {1, 3, 4, 20, 6, 9, 10}
#     {1, 2, -30, 3, 5, 6, 30}
#     3
# **********************************************************************
# File "__main__", line 18, in __main__.chains
# Failed example:
#     chains({10, 12, 13, 14, 16, 21, 26, 36, 37, 38, 50},               {2, 4, 7, 10, 16, 20, 100}, 10)
# Expected:
#     [10, 12, 16, 26] by successively adding 2, 4, 10
#     [10, 12, 16, 36] by successively adding 2, 4, 20
#     [10, 14, 16, 26] by successively adding 4, 2, 10
#     [10, 14, 16, 36] by successively adding 4, 2, 20
#     [10, 14, 21, 37] by successively adding 4, 7, 16
#     [10, 26, 36, 38] by successively adding 16, 10, 2
# Got:
#     {36, 37, 38, 10, 12, 13, 14, 16, 50, 21, 26}
#     {16, 2, 100, 4, 20, 7, 10}
#     10
# **********************************************************************
# File "__main__", line 36, in __main__.unknown_words
# Failed example:
#     unknown_words('edgar_poe_2.txt')
# Expected:
#     There are unknown words of length greater than 2.
#       - Of length 8:
#           Practise
#       - Of length 9:
#           Fortunato
#           Imposture
#           Redresser
#       - Of length 10:
#           Immolation
#       - Of length 11:
#           Unredressed
#       - Of length 12:
#           Definitively
#       - Of length 14:
#           Definitiveness
#       - Of length 15:
#           Connoisseurship
# Got:
#     There are unknown words of length greater than 2.
#     	- Of length 8:
#     		Practise
#     	- Of length 9:
#     		Fortunato
#     		Imposture
#     		Redresser
#     	- Of length 10:
#     		Immolation
#     	- Of length 11:
#     		Unredressed
#     	- Of length 12:
#     		Definitively
#     	- Of length 14:
#     		Definitiveness
#     	- Of length 15:
#     		Connoisseurship
# **********************************************************************
# File "__main__", line 56, in __main__.unknown_words
# Failed example:
#     unknown_words('oscar_wild_2.txt')
# Expected:
#     There are unknown words of length greater than 2.
#       - Of length 5:
#           Renan
#       - Of length 7:
#           Realise
#       - Of length 8:
#           Flaubert
#       - Of length 10:
#           Neighbours
#       - Of length 11:
#           Misdirected
# Got:
#     There are unknown words of length greater than 2.
#     	- Of length 5:
#     		Renan
#     	- Of length 7:
#     		Realise
#     	- Of length 8:
#     		Flaubert
#     	- Of length 10:
#     		Neighbours
#     	- Of length 11:
#     		Misdirected
# **********************************************************************
# 2 items had failures:
#    6 of   6 in __main__.chains
#    2 of   4 in __main__.unknown_words
# ***Test Failed*** 8 failures.

# %%
def chains(sums, summands, a):
    for L in sorted(_chains(sums, summands, a)):
        if len(L) == 1:
            print(L)
        else:
            print(L, 'by successively adding',
                  ', '.join(str(L[i + 1] - L[i])
                                for i in range(len(L) - 1)
                           )
                 )

def _chains(sums, summands, a):
    
    possible_sums = {a}
    for summand in summands:
        possible_sums.add(a + summand)

    print(f'Sums = {sums}')    
    print(f'Possible Sums = {possible_sums}')
    print(a)
    
    new_sums = {None}
    for sum in sums:
        if sum >= a and sum in possible_sums:
            new_sums.add(sum)
    
    
    new_sums.remove(None)
    print(f'Sums New = {new_sums}')

    return new_sums, a
    # REPLACE THE RETURN STATEMENT ABOVE WITH YOUR CODE

# %%
chains({11, 12, 13, 14, 15, 16}, {1, 2, 3, 4}, 11)
# Out:
# Sums = {16, 11, 12, 13, 14, 15}
# Possible Sums = {11, 12, 13, 14, 15}
# 11
# Sums New = {11, 12, 13, 14, 15}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[179], line 1
# ----> 1 chains({11, 12, 13, 14, 15, 16}, {1, 2, 3, 4}, 11)
#
# Cell In[175], line 2, in chains(sums, summands, a)
#       1 def chains(sums, summands, a):
# ----> 2     for L in sorted(_chains(sums, summands, a)):
#       3         if len(L) == 1:
#       4             print(L)
#
# TypeError: '<' not supported between instances of 'int' and 'set'

# %%
_chains({1, 2, 3}, {}, 4)
# Out:
# Sums = {1, 2, 3}
# Possible Sums = {4}
# 4
# Sums New = set()
# (set(), 4)

# %%
_chains({1, 2, 3}, {}, 2)
# Out:
# Sums = {1, 2, 3}
# Possible Sums = {2}
# 2
# Sums New = {2}
# ({2}, 2)
