# %%
# The words in the file are supposed to consist of nothing but letters
# (no apostrophes, no hyphens...), possibly immediately followed by
# a single full stop, exclamation mark, question mark,
# comma, colon or semicolon.
#
# There can be any amount of space anywhere between words, before the
# first word, and after the last word.
#
# We do not distinguish between words that only differ in cases.
# For instance, millionaires, Millionaires, MILLIONAIRES are
# 3 variants of the same word.
#
# You can assume that filename is the name of a file that exists
# in the working directory. Do NOT use an absolute path.
#
# The words of length greater than 2 are checked against the contents
# of dictionary.txt, also assumed to be stored in the working directory.
# Here too, do NOT use an absolute path.
#
# Unknown words (that is, words of length greater than 2 that are
# not found in dictionary.txt) are output only once, in capitalised form,
# in lexicographic order for each group, a group consisting of words
# all of the same length.
# Groups for shorter words are output before groups for longer words.

# Note that no tab is output anywhere, just single spaces.


from collections import defaultdict
import collections


def unknown_words(filename):
    '''
    >>> unknown_words('edgar_poe_1.txt')
    There are no unknown words of length greater than 2.
    >>> unknown_words('edgar_poe_2.txt')
    There are unknown words of length greater than 2.
      - Of length 8:
          Practise
      - Of length 9:
          Fortunato
          Imposture
          Redresser
      - Of length 10:
          Immolation
      - Of length 11:
          Unredressed
      - Of length 12:
          Definitively
      - Of length 14:
          Definitiveness
      - Of length 15:
          Connoisseurship
    >>> unknown_words('oscar_wild_1.txt')
    There are no unknown words of length greater than 2.
    >>> unknown_words('oscar_wild_2.txt')
    There are unknown words of length greater than 2.
      - Of length 5:
          Renan
      - Of length 7:
          Realise
      - Of length 8:
          Flaubert
      - Of length 10:
          Neighbours
      - Of length 11:
          Misdirected
    '''
    pass
    # REPLACE THE PASS STATEMENT ABOVE WITH YOUR CODE
               

if __name__ == '__main__':
    import doctest
    doctest.testmod()
# Out:
# **********************************************************************
# File "__main__", line 35, in __main__.unknown_words
# Failed example:
#     unknown_words('edgar_poe_1.txt')
# Expected:
#     There are no unknown words of length greater than 2.
# Got nothing
# **********************************************************************
# File "__main__", line 37, in __main__.unknown_words
# Failed example:
#     unknown_words('edgar_poe_2.txt')
# Expected:
#     There are unknown words of length greater than 2.
#       - Of length 8:
#           Practise
#       - Of length 9:
#           Fortunato
#           Imposture
#           Redresser
#       - Of length 10:
#           Immolation
#       - Of length 11:
#           Unredressed
#       - Of length 12:
#           Definitively
#       - Of length 14:
#           Definitiveness
#       - Of length 15:
#           Connoisseurship
# Got nothing
# **********************************************************************
# File "__main__", line 55, in __main__.unknown_words
# Failed example:
#     unknown_words('oscar_wild_1.txt')
# Expected:
#     There are no unknown words of length greater than 2.
# Got nothing
# **********************************************************************
# File "__main__", line 57, in __main__.unknown_words
# Failed example:
#     unknown_words('oscar_wild_2.txt')
# Expected:
#     There are unknown words of length greater than 2.
#       - Of length 5:
#           Renan
#       - Of length 7:
#           Realise
#       - Of length 8:
#           Flaubert
#       - Of length 10:
#           Neighbours
#       - Of length 11:
#           Misdirected
# Got nothing
# **********************************************************************
# 1 items had failures:
#    4 of   4 in __main__.unknown_words
# ***Test Failed*** 4 failures.

# %%
# The words in the file are supposed to consist of nothing but letters
# (no apostrophes, no hyphens...), possibly immediately followed by
# a single full stop, exclamation mark, question mark,
# comma, colon or semicolon.
#
# There can be any amount of space anywhere between words, before the
# first word, and after the last word.
#
# We do not distinguish between words that only differ in cases.
# For instance, millionaires, Millionaires, MILLIONAIRES are
# 3 variants of the same word.
#
# You can assume that filename is the name of a file that exists
# in the working directory. Do NOT use an absolute path.
#
# The words of length greater than 2 are checked against the contents
# of dictionary.txt, also assumed to be stored in the working directory.
# Here too, do NOT use an absolute path.
#
# Unknown words (that is, words of length greater than 2 that are
# not found in dictionary.txt) are output only once, in capitalised form,
# in lexicographic order for each group, a group consisting of words
# all of the same length.
# Groups for shorter words are output before groups for longer words.

# Note that no tab is output anywhere, just single spaces.


from collections import defaultdict


def unknown_words(filename):
    '''
    >>> unknown_words('edgar_poe_1.txt')
    There are no unknown words of length greater than 2.
    >>> unknown_words('edgar_poe_2.txt')
    There are unknown words of length greater than 2.
      - Of length 8:
          Practise
      - Of length 9:
          Fortunato
          Imposture
          Redresser
      - Of length 10:
          Immolation
      - Of length 11:
          Unredressed
      - Of length 12:
          Definitively
      - Of length 14:
          Definitiveness
      - Of length 15:
          Connoisseurship
    >>> unknown_words('oscar_wild_1.txt')
    There are no unknown words of length greater than 2.
    >>> unknown_words('oscar_wild_2.txt')
    There are unknown words of length greater than 2.
      - Of length 5:
          Renan
      - Of length 7:
          Realise
      - Of length 8:
          Flaubert
      - Of length 10:
          Neighbours
      - Of length 11:
          Misdirected
    '''
    dictionary = 'dictionary.txt'
    dict_words = []
    unknown_words = {}
    with open(dictionary) as question_dict:
        lines = question_dict.readlines()
        for line in lines:
            dict_words.append(line.strip('\n'))
        
    with open(filename) as file:
        lines = file.readlines()
        
        for line in lines:
            current_line = line.replace(',','').replace('.','').replace('\n','').replace('!','').replace('?','').replace(';','')
            words = current_line.split(' ')
            for word in words:
                if len(word) > 2 and word.upper() not in dict_words:
#                     print(word)
                    if len(word) in unknown_words.keys():
                        if word.capitalize() not in unknown_words[len(word)]:
                            unknown_words[len(word)].append(word.capitalize())
                    else:
                        unknown_words[len(word)] = [word.capitalize()]
                        
    # sort dictionary
    unknown_words = sorted(unknown_words.items())
#     print(unknown_words)
                    
    # Outputting Text
    if len(unknown_words) == 0:
        print("There are no unknown words of length greater than 2.")
    else: 
        print("There are unknown words of length greater than 2.")
        for length, l_words in unknown_words:
            sl_words = sorted(l_words)
            print(f'  - Of length {length}:')
            for word in sl_words:
                print(f'      {word}')
    # REPLACE THE PASS STATEMENT ABOVE WITH YOUR CODE
               

if __name__ == '__main__':
    import doctest
    doctest.testmod()
