# %%
# Will be tested with height a strictly positive integer.
def gen_row(start, length):
    row = []
    
    for i in range(length):
        row.append(str(start))
        if start == 9:
            start = 0
        else:
            start += 1
    return start, ''.join(row)

def f(height):
    '''
    >>> f(1)
    0
    >>> f(2)
     0
    123
    >>> f(3)
      0
     123
    45678
    >>> f(4)
       0
      123
     45678
    9012345
    >>> f(5)
        0
       123
      45678
     9012345
    678901234
    >>> f(6)
         0
        123
       45678
      9012345
     678901234
    56789012345
    >>> f(20)
                       0
                      123
                     45678
                    9012345
                   678901234
                  56789012345
                 6789012345678
                901234567890123
               45678901234567890
              1234567890123456789
             012345678901234567890
            12345678901234567890123
           4567890123456789012345678
          901234567890123456789012345
         67890123456789012345678901234
        5678901234567890123456789012345
       678901234567890123456789012345678
      90123456789012345678901234567890123
     4567890123456789012345678901234567890
    123456789012345678901234567890123456789
    '''
    # INSERT YOUR CODE HERE

    
    num = 0
    for i in range(height):
        num, row = gen_row(num, 1 + i * 2)
        print(' ' * (height - (i+1)), f'{row}', sep='')


if __name__ == '__main__':
    import doctest
    doctest.testmod()
    f(10)
# Out:
#          0
#         123
#        45678
#       9012345
#      678901234
#     56789012345
#    6789012345678
#   901234567890123
#  45678901234567890
# 1234567890123456789
